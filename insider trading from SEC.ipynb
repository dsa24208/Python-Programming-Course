# %%
import pandas as pd
import numpy as np

# %%
#SEC playin hard to get, i'm a computer beep boop
import requests

url = 'https://sec.report/Insider-Trades'

header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

r = requests.get(url, headers=header)

insider = pd.read_html(r.text)

# %%
insider = insider[0]

# %%
insider
# Out:
#                           Filed DateTransaction Report  \
# 0      2021-03-02 16:33:42 Form 4 0001567619-21-005375
# 1                                    SELL Common Stock
# 2      2021-03-02 16:33:37 Form 4 0001209191-21-016002
# 3                                    SELL Common Stock
# 4                                    SELL Common Stock
# ..                                                 ...
# 846                          SELL Class A Common Stock
# 847  SELL OPTIONRestricted Stock Unit Class B Common S
# 848    BUY OPTIONClass B Common Stock Class A Common S
# 849   SELL OPTIONClass B Common Stock Class A Common S
# 850   SELL OPTIONClass B Common Stock Class A Common S
#
#                                    Issuer  \
# 0                    Public Storage [PSA]
# 1                    357 shares @ $233.94
# 2               ASPEN AEROGELS INC [ASPN]
# 3                    1081 shares @ $22.25
# 4                    4092 shares @ $22.25
# ..                                    ...
# ...

# %%
insider.insert(0, "Stock", insider.Issuer)

# %%
insider
# Out:
#                                     Stock  \
# 0                    Public Storage [PSA]
# 1                    357 shares @ $233.94
# 2               ASPEN AEROGELS INC [ASPN]
# 3                    1081 shares @ $22.25
# 4                    4092 shares @ $22.25
# ..                                    ...
# 846                 131066 shares @ $0.00
# 847   256594 [256594 shares] @ $- [$0.00]
# 848   256594 [256594 shares] @ $- [$0.00]
# 849  125528 [125528 shares] @ $- [$46.13]
# 850   125528 [131066 shares] @ $- [$0.00]
#
#                           Filed DateTransaction Report  \
# 0      2021-03-02 16:33:42 Form 4 0001567619-21-005375
# 1                                    SELL Common Stock
# 2      2021-03-02 16:33:37 Form 4 0001209191-21-016002
# 3                                    SELL Common Stock
# 4                                    SELL Common Stock
# ..                                                 ...
# 846                          SELL Class A Common Stock
# ...

# %%
count = 0
for i in changelist:
    if changelist[count]:
        insider.Stock[count] = np.nan
        count = count + 1
    else:
        count = count + 1

# %%
changelist = insider.Stock.str.contains('@')

# %%
insider
# Out:
#                          Stock  \
# 0         Public Storage [PSA]
# 1                          NaN
# 2    ASPEN AEROGELS INC [ASPN]
# 3                          NaN
# 4                          NaN
# ..                         ...
# 846                        NaN
# 847                        NaN
# 848                        NaN
# 849                        NaN
# 850                        NaN
#
#                           Filed DateTransaction Report  \
# 0      2021-03-02 16:33:42 Form 4 0001567619-21-005375
# 1                                    SELL Common Stock
# 2      2021-03-02 16:33:37 Form 4 0001209191-21-016002
# 3                                    SELL Common Stock
# 4                                    SELL Common Stock
# ..                                                 ...
# 846                          SELL Class A Common Stock
# 847  SELL OPTIONRestricted Stock Unit Class B Common S
# 848    BUY OPTIONClass B Common Stock Class A Common S
# ...

# %%
#ffill down stock columns, find a way to keep dates,
#the delete rows with issuer stock tickers, get rid of reporter/holding column - then fight with buy vs sell
#maybe keep if buy in list then shorten to first 3? removing options?
